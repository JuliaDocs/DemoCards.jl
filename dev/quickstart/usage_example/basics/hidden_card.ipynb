# %% [markdown]
# # This is a hidden card

# %% [markdown]
# This card doesn't get displayed in quickstart index page page and can only be
# viewed with relink `hidden card`.

# %% [markdown]
# Note that hidden cards are still processed by DemoCards to get you necessary assets.

# %%
using ImageCore, ImageTransformations, TestImages

imresize(testimage("camera"); ratio=0.25)
# Out:
# 128×128 Array{Gray{N0f8},2} with eltype ColorTypes.Gray{FixedPointNumbers.N0f8}:
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.608)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.62)      Gray{N0f8}(0.592)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.616)     Gray{N0f8}(0.584)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.6)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.608)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.62)      Gray{N0f8}(0.592)
#  Gray{N0f8}(0.6)    Gray{N0f8}(0.612)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.604)     Gray{N0f8}(0.604)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.561)  Gray{N0f8}(0.557)     Gray{N0f8}(0.369)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.471)  …  Gray{N0f8}(0.478)
#  Gray{N0f8}(0.576)  Gray{N0f8}(0.49)      Gray{N0f8}(0.447)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.431)     Gray{N0f8}(0.42)
#  Gray{N0f8}(0.416)  Gray{N0f8}(0.392)     Gray{N0f8}(0.435)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.427)     Gray{N0f8}(0.408)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.361)  …  Gray{N0f8}(0.388)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.455)     Gray{N0f8}(0.475)
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.62)      Gray{N0f8}(0.459)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
